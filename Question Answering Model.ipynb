# %%
import transformers

# %%
# !pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in c:\users\sharm\anaconda3\lib\site-packages (4.10.2)
# Requirement already satisfied: datasets in c:\users\sharm\anaconda3\lib\site-packages (1.11.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (2.25.1)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (5.0.0)
# Requirement already satisfied: pandas in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (1.2.4)
# Requirement already satisfied: xxhash in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: packaging in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (20.9)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (2021.8.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (1.20.1)
# Requirement already satisfied: huggingface-hub<0.1.0 in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (0.0.16)
# Requirement already satisfied: tqdm>=4.42 in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (4.59.0)
# Requirement already satisfied: dill in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (0.3.4)
# Requirement already satisfied: multiprocess in c:\users\sharm\anaconda3\lib\site-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: typing-extensions in c:\users\sharm\anaconda3\lib\site-packages (from huggingface-hub<0.1.0->datasets) (3.7.4.3)
# Requirement already satisfied: filelock in c:\users\sharm\anaconda3\lib\site-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharm\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sharm\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sharm\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\sharm\anaconda3\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sharm\anaconda3\lib\site-packages (from transformers) (5.4.1)
# Requirement already satisfied: sacremoses in c:\users\sharm\anaconda3\lib\site-packages (from transformers) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sharm\anaconda3\lib\site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sharm\anaconda3\lib\site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sharm\anaconda3\lib\site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\sharm\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: joblib in c:\users\sharm\anaconda3\lib\site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in c:\users\sharm\anaconda3\lib\site-packages (from sacremoses->transformers) (7.1.2)

# %%
import pandas as pd
import numpy as np
import torch
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer

# %%
coqa = pd.read_json('http://downloads.cs.stanford.edu/nlp/data/coqa/coqa-train-v1.0.json')
coqa.head()
# Out:
#    version                                               data
# 0        1  {'source': 'wikipedia', 'id': '3zotghdk5ibi9ce...
# 1        1  {'source': 'cnn', 'id': '3wj1oxy92agboo5nlq4r7...
# 2        1  {'source': 'gutenberg', 'id': '3bdcf01ogxu7zdn...
# 3        1  {'source': 'cnn', 'id': '3ewijtffvo7wwchw6rtya...
# 4        1  {'source': 'gutenberg', 'id': '3urfvvm165iantk...

# %%
del coqa["version"]

# %%
#required columns in our dataframe
cols = ["text","question","answer"]
#list of lists to create our dataframe
comp_list = []
for index, row in coqa.iterrows():
    for i in range(len(row["data"]["questions"])):
        temp_list = []
        temp_list.append(row["data"]["story"])
        temp_list.append(row["data"]["questions"][i]["input_text"])
        temp_list.append(row["data"]["answers"][i]["input_text"])
        comp_list.append(temp_list)
new_df = pd.DataFrame(comp_list, columns=cols) 
#saving the dataframe to csv file for further loading
new_df.to_csv("CoQA_data.csv", index=False)

# %%
data = pd.read_csv("CoQA_data.csv")
data.head()
# Out:
#                                                 text  \
# 0  The Vatican Apostolic Library (), more commonl...
# 1  The Vatican Apostolic Library (), more commonl...
# 2  The Vatican Apostolic Library (), more commonl...
# 3  The Vatican Apostolic Library (), more commonl...
# 4  The Vatican Apostolic Library (), more commonl...
#
#                             question                               answer
# 0  When was the Vat formally opened?  It was formally established in 1475
# 1           what is the library for?                             research
# 2                 for what subjects?                     history, and law
# 3                               and?     philosophy, science and theology
# 4          what was started in 2014?                           a  project

# %%
print("Number of question and answers: ", len(data))
# Out:
# Number of question and answers:  108647

# %%
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
random_num = np.random.randint(0,len(data))
question = data["question"][random_num]
text = data["text"][random_num]

# %%
input_ids = tokenizer.encode(question, text)
print("The input has a total of {} tokens.".format(len(input_ids)))
# Out:
# The input has a total of 335 tokens.

# %%
tokens = tokenizer.convert_ids_to_tokens(input_ids)
for token, id in zip(tokens, input_ids):
    print('{:8}{:8,}'.format(token,id))
# Out:
# [CLS]        101
# who        2,040
# is         2,003
# cu        12,731
# ##i        2,072
# shang     29,382
# ##yu      10,513
# ?          1,029
# [SEP]        102
# why        2,339
# do         2,079
# you        2,017
# study      2,817
# ?          1,029
# many       2,116
# students   2,493
# would      2,052
# simply     3,432
# reply      7,514
# :          1,024
# "          1,000
# to         2,000
# get        2,131
# good       2,204
# result     2,765
# in         1,999
# the        1,996
# college    2,267
# entrance   4,211
# examination   7,749
# .          1,012
# "          1,000
# for        2,005
# several    2,195
# years      2,086
# ,          1,010
# many       2,116
# have       2,031
# spoken     5,287
# out        2,041
# against    2,114
# the        1,996
# exams     13,869
# .          1,012
# some       2,070
# say        2,360
# they       2,027
# have       2,031
# turned     2,357
# children   2,336
# into       2,046
# studying   5,702
# machines   6,681
# .          1,012
# others     2,500
# think      2,228
# that       2,008
# one        2,028
# exam      11,360
# cannot     3,685
# possibly   4,298
# _          1,035
# a          1,037
# student    3,076
# '          1,005
# s          1,055
# true       2,995
# level      2,504
# of         1,997
# knowledge   3,716
# .          1,012
# so         2,061
# ,          1,010
# should     2,323
# the        1,996
# exams     13,869
# be         2,022
# canceled  13,261
# ?          1,029
# minister   2,704
# of         1,997
# education   2,495
# yuan      11,237
# gui       26,458
# ##ren      7,389
# doesn      2,987
# '          1,005
# t          1,056
# think      2,228
# so         2,061
# .          1,012
# "          1,000
# officials   4,584
# and        1,998
# the        1,996
# rich       4,138
# might      2,453
# take       2,202
# advantage   5,056
# if         2,065
# the        1,996
# college    2,267
# entrance   4,211
# examination   7,749
# were       2,020
# called     2,170
# off        2,125
# .          1,012
# and        1,998
# life       2,166
# would      2,052
# be         2,022
# more       2,062
# difficult   3,697
# for        2,005
# poor       3,532
# children   2,336
# .          1,012
# however    2,174
# ,          1,010
# we         2,057
# do         2,079
# need       2,342
# to         2,000
# change     2,689
# the        1,996
# exams     13,869
# ,          1,010
# "          1,000
# yuan      11,237
# said       2,056
# on         2,006
# march      2,233
# 7          1,021
# .          1,012
# he         2,002
# has        2,038
# put        2,404
# an         2,019
# exam      11,360
# reforms    8,818
# at         2,012
# the        1,996
# center     2,415
# of         1,997
# his        2,010
# fourth     2,959
# year       2,095
# in         1,999
# office     2,436
# .          1,012
# "          1,000
# i          1,045
# think      2,228
# the        1,996
# exam      11,360
# is         2,003
# a          1,037
# fair       4,189
# way        2,126
# to         2,000
# choose     5,454
# talented  10,904
# people     2,111
# .          1,012
# but        2,021
# it         2,009
# should     2,323
# pay        3,477
# more       2,062
# attention   3,086
# to         2,000
# all        2,035
# -          1,011
# around     2,105
# personal   3,167
# qualities  11,647
# ,          1,010
# not        2,025
# just       2,074
# grades     7,022
# ,          1,010
# "          1,000
# said       2,056
# cu        12,731
# ##i        2,072
# shang     29,382
# ##yu      10,513
# ,          1,010
# a          1,037
# senior     3,026
# 3          1,017
# student    3,076
# in         1,999
# sichuan   20,980
# .          1,012
# the        1,996
# college    2,267
# entrance   4,211
# examination   7,749
# was        2,001
# restored   5,854
# in         1,999
# 1977       3,355
# .          1,012
# from       2,013
# then       2,059
# to         2,000
# 2007       2,289
# ,          1,010
# 46         4,805
# .          1,012
# 85         5,594
# million    2,454
# people     2,111
# have       2,031
# entered    3,133
# higher     3,020
# education   2,495
# through    2,083
# the        1,996
# exam      11,360
# .          1,012
# according   2,429
# to         2,000
# survey     5,002
# by         2,011
# the        1,996
# ministry   3,757
# of         1,997
# education   2,495
# ,          1,010
# 90         3,938
# percent    3,867
# of         1,997
# people     2,111
# who        2,040
# participate   5,589
# believed   3,373
# the        1,996
# college    2,267
# entrance   4,211
# examination   7,749
# could      2,071
# in         1,999
# some       2,070
# way        2,126
# change     2,689
# a          1,037
# person     2,711
# '          1,005
# s          1,055
# life       2,166
# ,          1,010
# especially   2,926
# for        2,005
# poor       3,532
# students   2,493
# in         1,999
# the        1,996
# countryside  10,833
# .          1,012
# the        1,996
# college    2,267
# entrance   4,211
# examination   7,749
# is         2,003
# not        2,025
# the        1,996
# only       2,069
# way        2,126
# to         2,000
# become     2,468
# a          1,037
# successful   3,144
# person     2,711
# .          1,012
# however    2,174
# ,          1,010
# the        1,996
# process    2,832
# of         1,997
# preparing   8,225
# for        2,005
# the        1,996
# exam      11,360
# is         2,003
# a          1,037
# good       2,204
# experience   3,325
# ,          1,010
# said       2,056
# shen      21,882
# hui       17,504
# ,          1,010
# a          1,037
# math       8,785
# teacher    3,836
# at         2,012
# gao       17,377
# ##you     29,337
# middle     2,690
# school     2,082
# in         1,999
# jiangsu   28,091
# .          1,012
# "          1,000
# through    2,083
# it         2,009
# students   2,493
# can        2,064
# learn      4,553
# many       2,116
# things     2,477
# ,          1,010
# such       2,107
# as         2,004
# how        2,129
# to         2,000
# deal       3,066
# with       2,007
# stress     6,911
# and        1,998
# how        2,129
# to         2,000
# arrange   13,621
# a          1,037
# learning   4,083
# plan       2,933
# .          1,012
# "          1,000
# shen      21,882
# said       2,056
# .          1,012
# [SEP]        102

# %%
#first occurence of [SEP] token
sep_idx = input_ids.index(tokenizer.sep_token_id)
print("SEP token index: ", sep_idx)
#number of tokens in segment A (question) - this will be one more than the sep_idx as the index in Python starts from 0
num_seg_a = sep_idx+1
print("Number of tokens in segment A: ", num_seg_a)
#number of tokens in segment B (text)
num_seg_b = len(input_ids) - num_seg_a
print("Number of tokens in segment B: ", num_seg_b)
#creating the segment ids
segment_ids = [0]*num_seg_a + [1]*num_seg_b
#making sure that every input token has a segment id
assert len(segment_ids) == len(input_ids)
# Out:
# SEP token index:  8
# Number of tokens in segment A:  9
# Number of tokens in segment B:  326

# %%
#token input_ids to represent the input and token segment_ids to differentiate our segments - question and text
output = model(torch.tensor([input_ids]),  token_type_ids=torch.tensor([segment_ids]))

# %%
#tokens with highest start and end scores
answer_start = torch.argmax(output.start_logits)
answer_end = torch.argmax(output.end_logits)
if answer_end >= answer_start:
    answer = " ".join(tokens[answer_start:answer_end+1])
else:
    print("I am unable to find the answer to this question. Can you please ask another question?")
    
print("\nQuestion:\n{}".format(question.capitalize()))
print("\nAnswer:\n{}.".format(answer.capitalize()))


answer = tokens[answer_start]
for i in range(answer_start+1, answer_end+1):
    if tokens[i][0:2] == "##":
        answer += tokens[i][2:]
    else:
        answer += " " + tokens[i]
# Out:
# Question:
# Who is cui shangyu?
#
# Answer:
# A senior 3 student in sichuan.

# %%
answer = tokens[answer_start]
for i in range(answer_start+1, answer_end+1):
    if tokens[i][0:2] == "##":
        answer += tokens[i][2:]
    else:
        answer += " " + tokens[i]

# %%
def question_answer(question, text):
    
    #tokenize question and text as a pair
    input_ids = tokenizer.encode(question, text)
    
    #string version of tokenized ids
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    
    #segment IDs
    #first occurence of [SEP] token
    sep_idx = input_ids.index(tokenizer.sep_token_id)
    #number of tokens in segment A (question)
    num_seg_a = sep_idx+1
    #number of tokens in segment B (text)
    num_seg_b = len(input_ids) - num_seg_a
    
    #list of 0s and 1s for segment embeddings
    segment_ids = [0]*num_seg_a + [1]*num_seg_b
    assert len(segment_ids) == len(input_ids)
    
    #model output using input_ids and segment_ids
    output = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]))
    
    #reconstructing the answer
    a_start = torch.argmax(output.start_logits)
    a_end = torch.argmax(output.end_logits)
    if a_end >= a_start:
        a = tokens[a_start]
        for i in range(a_start+1, a_end+1):
            if tokens[i][0:2] == "##":
                a += tokens[i][2:]
            else:
                a += " " + tokens[i]
                
    if a.startswith("[CLS]"):
        a = "Unable to find the answer to your question."
    
    responseText = a
    print(responseText)
    #print("\nPredicted answer:\n{}".format(a.capitalize()))

# %%
#your text passage goes here.
text = "Victoria University (VU or Vic Uni) is a public research university based in Melbourne, Victoria, Australia. It is one of only six dual-sector universities in Australia, providing courses in both higher education and Technical and Further Education (TAFE). 2016 marked VU's centenary as an educational institution and its 25th anniversary as a university. The university has several campuses in Melbourne Central Business District, Melbourne Western Region, and in Sydney, comprising six academic colleges, six research institutes, seven research centres and VU's Victoria Polytechnic (providing vocational education and training). The new VU city Tower will be Melbourne’s tallest vertical campus and is due for completion in 2021. It also offers courses at partner institutions throughout Asia. Victoria University Melbourne is a globally recognised institution, ranking in the top 2% of universities worldwide (2021 Times Higher Education World University Rankings), and 56th globally (2nd in Victoria) in the 2020 Times Higher Education (THE) Young University Rankings.VU was also ranked 11th in the world (1st in Australia) for Peace, Justice and Strong Institutions (Times Higher Education Impact Rankings 2021). In 2018, Victoria University became the first university in Australia to adopt the block model style of teaching for all undergraduate courses. Under VU’s Block Model, students’ study and complete one unit at a time over a four-week period (a block), working collaboratively in smaller classes. Unlike the standard model of tertiary education in Australia, students studying under VU’s Block Model focus on learning one unit every four weeks, rather than juggling multiple units and assessments at the same time within a semester. Since introducing the VU Block Model, pass rates amongst onshore undergraduate students have increased, with over 90% of students passing their enrolled units in 2020. Overall grades for this cohort has also grown, with over 60% receiving distinction levels or higher in the same year. This improvement in academic results is complemented by higher levels of learner engagement amongst its students. The latest Australian Government 2020 Student Experience Survey (SES) has Victoria University now ranked by students as the top University in Victoria, and third overall in Australia, for learner engagement. "
question = "What is VU block Model?"

# %%
test = question_answer(question, text)
# Out:
# students ’ study and complete one unit at a time over a four - week period ( a block ) , working collaboratively in smaller classes

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\sharm\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\sharm\anaconda3\lib\site-packages (from flask) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sharm\anaconda3\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\sharm\anaconda3\lib\site-packages (from flask) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\sharm\anaconda3\lib\site-packages (from flask) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sharm\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %%
# !pip install flask-ngrok
# Out:
# Requirement already satisfied: flask-ngrok in c:\users\sharm\anaconda3\lib\site-packages (0.0.25)
# Requirement already satisfied: Flask>=0.8 in c:\users\sharm\anaconda3\lib\site-packages (from flask-ngrok) (1.1.2)
# Requirement already satisfied: requests in c:\users\sharm\anaconda3\lib\site-packages (from flask-ngrok) (2.25.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\sharm\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sharm\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\sharm\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\sharm\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sharm\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sharm\anaconda3\lib\site-packages (from requests->flask-ngrok) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharm\anaconda3\lib\site-packages (from requests->flask-ngrok) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from requests->flask-ngrok) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sharm\anaconda3\lib\site-packages (from requests->flask-ngrok) (2.10)

# %%
# !pip install dialogflow
# Out:
# Requirement already satisfied: dialogflow in c:\users\sharm\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in c:\users\sharm\anaconda3\lib\site-packages (from dialogflow) (1.31.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (2.25.1)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (3.18.0)
# Requirement already satisfied: pytz in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (2021.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (20.9)
# Requirement already satisfied: six>=1.13.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (1.53.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (52.0.0.post20210125)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (1.35.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in c:\users\sharm\appdata\roaming\python\python38\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (1.32.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sharm\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sharm\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (4.2.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from packaging>=14.3->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sharm\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->dialogflow) (2020.12.5)

# %%
# !pip install google-api-core
# Out:
# Requirement already satisfied: google-api-core in c:\users\sharm\anaconda3\lib\site-packages (1.31.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (2.25.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (20.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (1.53.0)
# Requirement already satisfied: pytz in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (2021.1)
# Requirement already satisfied: six>=1.13.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (1.15.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (1.35.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (52.0.0.post20210125)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-api-core) (3.18.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sharm\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sharm\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sharm\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core) (4.2.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from packaging>=14.3->google-api-core) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sharm\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core) (0.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharm\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (2020.12.5)

# %%
import flask
import os
from flask import send_from_directory, request

app = flask.Flask(__name__)

@app.route('/favicon.ico')
def favicon():
    return send_from_directory(os.path.join(app.root_path, 'static'),
                               'favicon.ico', mimetype='image/favicon.png')

@app.route('/')
@app.route('/home')
def home():
    return "Hello World"

@app.route('/webhook', methods=['POST'])
def webhook():
    req = request.get_json(force=True)
    
    #WebhookResponse = ''
    
    query_result = req.get('queryResult')
    
    query_Text = query_result.get('queryText')
    
    question = str(query_Text)
    
    print(query_Text)
    print(query_result)
    
    WebhookResponse = question_answer(question, text)
    

    return {
        'fulfillmentText' : WebhookResponse
        }

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# what is vu block model?
# {'queryText': 'what is vu block model?', 'parameters': {'geo-city': ''}, 'allRequiredParamsPresent': True, 'fulfillmentMessages': [{'text': {'text': ['']}}], 'outputContexts': [{'name': 'projects/askme-krct/locations/global/agent/sessions/06cbc855-9e18-9728-d440-0cff8fde808b/contexts/__system_counters__', 'parameters': {'no-input': 0.0, 'no-match': 0.0, 'geo-city': '', 'geo-city.original': ''}}], 'intent': {'name': 'projects/askme-krct/locations/global/agent/intents/ea3a9c3f-b869-4b91-9eb7-b94a86a87b1b', 'displayName': 'bert model'}, 'intentDetectionConfidence': 1.0, 'languageCode': 'en'}
# 127.0.0.1 - - [24/Sep/2021 12:26:39] "POST /webhook HTTP/1.1" 200 -
# students ’ study and complete one unit at a time over a four - week period ( a block ) , working collaboratively in smaller classes
